# %%
#reading and writing to a file
file = open("myfile.txt", "r") #r is for read mode

# %%
content = file.read()  #read the content of the file
print(content)  #print the content of the file
file.close()  #close the file
# Out:
# this will be read or written

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data.csv")  #read the csv file ie in this case data.csv
print(df.head())  #print the first 5 rows of the dataframe
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
import numpy as np
import matplotlib.pyplot as plt

print(np.__version__)
plt.plot([1, 2, 3], [4, 5, 6])
plt.title("Test Plot")
plt.show()
# Out:
# 1.26.4

# %%
import pandas as pd

#creating my dataframe
data = {
    "Sport": ["football", "basketball", "swimming", "Hockey"],
    "medal": ["gold", "silver", "bronze", "gold"],
    "country": ["BRAZIL", "USA", "CHINA", "Canada"],
    "year": [2022, 2012, 2024, 2023],
    "age": [24, 27, 19, 28]   
}
df = pd.DataFrame(data)  #created a dataframe from the data dictionary above
print(df)  #print the dataframe
print(df["medal"])
# Out:
#         Sport   medal country  year  age
# 0    football    gold  BRAZIL  2022   24
# 1  basketball  silver     USA  2012   27
# 2    swimming  bronze   CHINA  2024   19
# 3      Hockey    gold  Canada  2023   28
# 0      gold
# 1    silver
# 2    bronze
# 3      gold
# Name: medal, dtype: object

# %%
import numpy as np
#create an array
a = np.array([[3,5,7,8]])
print(a * 3)
print(np.mean(a))
print(a.shape)

# 2D array
b = np.array([[1, 2], [3, 4]])
print(b.shape)      # (2, 2)
# Out:
# [[ 9 15 21 24]]
# 5.75
# (1, 4)
# (2, 2)

# %%
import matplotlib.pyplot as plt
# Plotting a simple line graph
x = [5, 10, 15, 20]
y = [-5, 5, 10, 15]
plt.plot(x,y)
plt.title("Simple Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()  #show the plot

# Plotting a bar chart
plt.bar(["Uganda", "Kenya", "Tanzania"], [1000, 2000, 1500])
plt.title("Bar Chart Example")
plt.xlabel("Countries")
plt.ylabel("Population")
# Out:
# Text(0, 0.5, 'Population')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#load data from a CSV file
df = pd.read_csv("records.csv")

#calculate the average sales
avg_sales = np.mean(df["Sales"])
print("Average Sales:", avg_sales)
# Filter data
top_sellers = df[df['Sales'] > avg_sales]
plt.bar(top_sellers['Name'], top_sellers['Sales'])
plt.title("Top Sellers")
plt.show()
# Out:
# Average Sales: 2587.5

# %%
#data cleaning
#bad data handling 
#1.empty cells ie contains no entry
#2.wrong format ie dates and currency 30/05/2025 not 30052025 or 30-05-2025
#3.wrong data ie data that doesnt make sense ie age of -23, age of 230
#4.duplicates ie more entries for the same person

# %%
#empty values
#first we check for empty values 
df = pd.read_csv("data.csv")
print(df.isnull().sum())
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df = pd.read_csv("Sales.csv")
print(df.isnull().sum())
# Out:
# Order ID         0
# Customer Name    1
# Order Date       0
# Product          0
# Quantity         1
# Unit Price       1
# Total Revenue    1
# dtype: int64

# %%
df = pd.read_csv("Mine.csv")
print(df.isnull().sum())
# Out:
# Duration    0
# Date        2
# Pulse       1
# Maxpulse    2
# Calories    4
# dtype: int64

# %%
#check for none numeric values
